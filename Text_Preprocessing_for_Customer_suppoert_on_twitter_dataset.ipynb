# %% [markdown]
# <a href="https://colab.research.google.com/github/vikrantyadav11234/NLP_Practice/blob/main/Text_Preprocessing_for_Customer_suppoert_on_twitter_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #
# In any ML task, cleaning or preprocessing the data is important as model building if not more. and when it comes to unstructured data like text, this process is even more important.
#
# Some of the common text preprocessing/ cleaning steps are:
# * Lower casing
# * Removal of punctuations
# * Removal of stop words
# * removal of frequent words
# * Removal of rare words
# * Number to words / ignoring numbers
# * Stemming
# * Lemmatization
# * removal of emojis
# * COnversion of emotion to words.
# * Conversion of emojis to words.
# * Removal of urls.
# * Chat word conversions
# * Spelling correction
# * remove emoticons

# %%
import pandas as pd
import numpy as np
import re
import spacy
import string

# %%
import nltk

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d thoughtvector/customer-support-on-twitter
# Out:
# Dataset URL: https://www.kaggle.com/datasets/thoughtvector/customer-support-on-twitter
# License(s): CC-BY-NC-SA-4.0
# ...
#  96% 161M/169M [00:02<00:00, 72.4MB/s]
# 100% 169M/169M [00:02<00:00, 70.1MB/s]

# %%
import zipfile
zip_ref = zipfile.ZipFile("/content/customer-support-on-twitter.zip")
zip_ref.extractall('/content')
zip_ref.close()

# %%
! ls "/content/twcs"
# Out:
# twcs.csv

# %%
full_df= pd.read_csv("/content/twcs/twcs.csv", nrows=100000)
df= full_df[["text"]]
df['text']=df['text'].astype(str)
full_df.head()
# Out:
# <ipython-input-7-9c49447b5002>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text']=df['text'].astype(str)
#    tweet_id   author_id  inbound                      created_at  \
# 0         1  sprintcare    False  Tue Oct 31 22:10:47 +0000 2017
# 1         2      115712     True  Tue Oct 31 22:11:45 +0000 2017
# 2         3      115712     True  Tue Oct 31 22:08:27 +0000 2017
# 3         4  sprintcare    False  Tue Oct 31 21:54:49 +0000 2017
# 4         5      115712     True  Tue Oct 31 21:49:35 +0000 2017
#
#                                                 text response_tweet_id  \
# 0  @115712 I understand. I would like to assist y...                 2
# 1      @sprintcare and how do you propose we do that               NaN
# ...

# %%
df['text_lower'] = df['text'].str.lower()
df.head()
# Out:
# <ipython-input-8-5e40701d7bd7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text_lower'] = df['text'].str.lower()
#                                                 text  \
# 0  @115712 I understand. I would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare I have sent several private messag...
# 3  @115712 Please send us a Private Message so th...
# 4                                 @sprintcare I did.
#
#                                           text_lower
# 0  @115712 i understand. i would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare i have sent several private messag...
# 3  @115712 please send us a private message so th...
# ...

# %%
df.head(25)
# Out:
#                                                  text  \
# 0   @115712 I understand. I would like to assist y...
# 1       @sprintcare and how do you propose we do that
# 2   @sprintcare I have sent several private messag...
# 3   @115712 Please send us a Private Message so th...
# 4                                  @sprintcare I did.
# 5   @115712 Can you please send us a private messa...
# 6           @sprintcare is the worst customer service
# 7   @115713 This is saddening to hear. Please shoo...
# 8   @sprintcare You gonna magically change your co...
# 9   @115713 We understand your concerns and we'd l...
# 10  @sprintcare Since I signed up with you....Sinc...
# 11  @115713 H there! We'd definitely like to work ...
# 12  @115714 y’all lie about your “great” connectio...
# 13  @115715 Please send me a private message so th...
# 14  @115714 whenever I contact customer support, t...
# 15         @115716 What information is incorrect? ^JK
# ...

# %% [markdown]
# # Removal of Punctuations

# %%
PUNCT_TO_REMOVE = string.punctuation
print(PUNCT_TO_REMOVE)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
def remove_punctuation(text):
  return text.translate(str.maketrans('','',PUNCT_TO_REMOVE))

df['text_to_punct']=df['text_lower'].apply(lambda text: remove_punctuation(text))
df.head()
# Out:
# <ipython-input-11-f51dbda66626>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text_to_punct']=df['text_lower'].apply(lambda text: remove_punctuation(text))
#                                                 text  \
# 0  @115712 I understand. I would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare I have sent several private messag...
# 3  @115712 Please send us a Private Message so th...
# 4                                 @sprintcare I did.
#
#                                           text_lower  \
# 0  @115712 i understand. i would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare i have sent several private messag...
# ...

# %% [markdown]
# ### Removal of stopwords

# %%
import nltk
nltk.download('stopwords')

from nltk.corpus import stopwords
', '.join(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# ...

# %%
STOPWORDS = set(stopwords.words('english'))
def remove_stopwords(text):
  return  ' '.join([word for word in str(text).split() if not word in STOPWORDS])

df['text_to_stop']=df['text_to_punct'].apply(lambda text: remove_stopwords(text))
df.head()
# Out:
# <ipython-input-13-c232ad7ae437>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text_to_stop']=df['text_to_punct'].apply(lambda text: remove_stopwords(text))
#                                                 text  \
# 0  @115712 I understand. I would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare I have sent several private messag...
# 3  @115712 Please send us a Private Message so th...
# 4                                 @sprintcare I did.
#
#                                           text_lower  \
# 0  @115712 i understand. i would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare i have sent several private messag...
# ...

# %% [markdown]
# ### Removal of frequent words

# %%
from collections import Counter
cnt = Counter()
for text in df['text_to_stop'].values:
  for word in text.split():
    cnt[word] += 1

cnt.most_common(10)
# Out:
# [('us', 15280),
#  ('please', 14172),
#  ('dm', 10290),
#  ('help', 9181),
#  ('hi', 8364),
#  ('thanks', 7794),
#  ('get', 7393),
#  ('sorry', 6913),
#  ('amazonhelp', 5916),
#  ('know', 5443)]

# %%
FREQWORDS= set ([w for (w,wc) in cnt.most_common(10)])
def remove_freqwords(text):
  return ' '.join([word for word in str(text).split() if word not in FREQWORDS])

df['text_to_ferq']= df['text_to_punct'].apply(lambda text: remove_freqwords(text))
df.head()
# Out:
# <ipython-input-16-46c0917be783>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text_to_ferq']= df['text_to_punct'].apply(lambda text: remove_freqwords(text))
#                                                 text  \
# 0  @115712 I understand. I would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare I have sent several private messag...
# 3  @115712 Please send us a Private Message so th...
# 4                                 @sprintcare I did.
#
#                                           text_lower  \
# 0  @115712 i understand. i would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare i have sent several private messag...
# ...

# %%
# Remove the rare words
n_rare_words = 20
RAREWORDS = set([w for (w,wc) in cnt.most_common()[:-n_rare_words-1:-1]])
print(RAREWORDS)
def remove_rarewords(text):
  return ' '.join([word for word in str(text).split() if word not in RAREWORDS])

df['text_to_rare']= df['text_to_ferq'].apply(lambda text: remove_rarewords(text))
df.head()
# Out:
# {'phone131027', 'httpstcoklebhaiotk', '230k', 'httpstcoldgvfgko7y', 'tale”', 'rajni', 'httpstcosxccepn7bl', 'knight’s', 'ulllrrrich', '7110', 'haveagainasked', '7109', 'lichtenstein', '144296', 'chaucer', 'therelets', 'enforcer', 'mailtemplate', 'httpstcoehp8tcbeds', '144295'}
# <ipython-input-17-43ca9c9a8188>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text_to_rare']= df['text_to_ferq'].apply(lambda text: remove_rarewords(text))
#                                                 text  \
# 0  @115712 I understand. I would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare I have sent several private messag...
# 3  @115712 Please send us a Private Message so th...
# ...

# %% [markdown]
# ### Stemming

# %%
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer('english')

def stem_words(text):
  return ' '.join([stemmer.stem(word) for word in text.split()])

df['text_to_stem']= df['text_to_rare'].apply(lambda text: stem_words(text))
df.head()
# Out:
#                                                 text  \
# 0  @115712 I understand. I would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare I have sent several private messag...
# 3  @115712 Please send us a Private Message so th...
# 4                                 @sprintcare I did.
#
#                                           text_lower  \
# 0  @115712 i understand. i would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare i have sent several private messag...
# 3  @115712 please send us a private message so th...
# 4                                 @sprintcare i did.
#
#                                        text_to_punct  \
# 0  115712 i understand i would like to assist you...
# 1       sprintcare and how do you propose we do that
# 2  sprintcare i have sent several private message...
# 3  115712 please send us a private message so tha...
# ...

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %% [markdown]
# ### Lemmatization

# %%
from nltk.stem import WordNetLemmatizer
lemma = WordNetLemmatizer()
def lemma_words(text):
  return ' '.join([lemma.lemmatize(word) for word in str(text).split()])

df['text_to_lemma']= df['text_to_rare'].apply(lambda text: lemma_words(text))
df.head()
# Out:
#                                                 text  \
# 0  @115712 I understand. I would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare I have sent several private messag...
# 3  @115712 Please send us a Private Message so th...
# 4                                 @sprintcare I did.
#
#                                           text_lower  \
# 0  @115712 i understand. i would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare i have sent several private messag...
# 3  @115712 please send us a private message so th...
# 4                                 @sprintcare i did.
#
#                                        text_to_punct  \
# 0  115712 i understand i would like to assist you...
# 1       sprintcare and how do you propose we do that
# 2  sprintcare i have sent several private message...
# 3  115712 please send us a private message so tha...
# ...

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
from nltk.corpus import wordnet
wordnet_map = {'N': wordnet.NOUN, "V":wordnet.VERB, "J":wordnet.ADJ, "R":wordnet.ADV}
def lemma_words(text):
  pos_tagged_text= nltk.pos_tag(text.split())
  return ' '.join([lemma.lemmatize(word, wordnet_map.get(pos[0],wordnet.NOUN)) for word, pos in pos_tagged_text])

df['text_to_pos_lemma']= df['text_to_rare'].apply(lambda text: lemma_words(text))

# %%
df.head()
# Out:
#                                                 text  \
# 0  @115712 I understand. I would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare I have sent several private messag...
# 3  @115712 Please send us a Private Message so th...
# 4                                 @sprintcare I did.
#
#                                           text_lower  \
# 0  @115712 i understand. i would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare i have sent several private messag...
# 3  @115712 please send us a private message so th...
# 4                                 @sprintcare i did.
#
#                                        text_to_punct  \
# 0  115712 i understand i would like to assist you...
# 1       sprintcare and how do you propose we do that
# 2  sprintcare i have sent several private message...
# 3  115712 please send us a private message so tha...
# ...

# %% [markdown]
# ### Remove urls

# %%
import re
def remove_urls(text):
  url_pattern = re.compile(r'https?://\S+|www\.\S+')
  return url_pattern.sub(r'', text)

# %%
text= "Driverless AI NLP blog post on https://colab.research.google.com/drive/19ByfREt-8P2N-CSENWyQ8-g__8-apNjp#scrollTo=IQvbcGDWFajd"
remove_urls(text)
# Out:
# 'Driverless AI NLP blog post on '

# %% [markdown]
# ### Remove HTML Tags
